# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to Change These)
school_data_to_load = "schools_complete.csv"
student_data_to_load = "students_complete.csv"

# Read School and Student Data File and store into Pandas Data Frames
school_data = pd.read_csv(school_data_to_load)
student_data = pd.read_csv(student_data_to_load)

# Combine the data into a single dataset
school_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])

# %%
school_data_complete
# Out:
#        Student ID       student_name gender grade         school_name  \
# 0               0       Paul Bradley      M   9th   Huang High School
# 1               1       Victor Smith      M  12th   Huang High School
# 2               2    Kevin Rodriguez      M  12th   Huang High School
# 3               3  Dr. Richard Scott      M  12th   Huang High School
# 4               4         Bonnie Ray      F   9th   Huang High School
# ...           ...                ...    ...   ...                 ...
# 39165       39165       Donna Howard      F  12th  Thomas High School
# 39166       39166          Dawn Bell      F  10th  Thomas High School
# 39167       39167     Rebecca Tanner      F   9th  Thomas High School
# 39168       39168       Desiree Kidd      F  10th  Thomas High School
# 39169       39169    Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score  School ID      type  size   budget
# 0                 66          79          0  District  2917  1910635
# 1                 94          61          0  District  2917  1910635
# 2                 90          60          0  District  2917  1910635
# 3                 67          58          0  District  2917  1910635
# 4                 97          84          0  District  2917  1910635
# ...              ...         ...        ...       ...   ...      ...
# 39165             99          90         14   Charter  1635  1043130
# 39166             95          70         14   Charter  1635  1043130
# 39167             73          84         14   Charter  1635  1043130
# 39168             99          90         14   Charter  1635  1043130
# 39169             95          75         14   Charter  1635  1043130
#
# [39170 rows x 11 columns]

# %%
school_count=len(school_data_complete["school_name"].unique())

# %%
student_count=len(school_data_complete["Student ID"].unique())

# %%
total_budget="$"+str(sum(school_data_complete["budget"].unique()))

# %%
math_avg=school_data_complete["math_score"].mean()

# %%
read_avg=school_data_complete["reading_score"].mean()

# %%
overall_avg=(math_avg+read_avg)/2

# %%
overall_avg
# Out:
# 80.43160582078121

# %%
math_pass_df=school_data_complete.loc[school_data_complete["math_score"]>69,:]

# %%
math_pass=len(math_pass_df["math_score"])

# %%
math_pass_rate=math_pass/student_count*100

# %%
math_pass_rate
# Out:
# 74.9808526933878

# %%
read_pass_df=school_data_complete.loc[school_data_complete["reading_score"]>69,:]

# %%
read_pass=len(read_pass_df["reading_score"])

# %%
read_pass_rate=read_pass/student_count*100

# %%
read_pass_rate
# Out:
# 85.80546336482001

# %%
district_summary_df=pd.DataFrame({"Total Schools":[school_count],
                                    "Total Students":[student_count],
                                    "Total Budget":[total_budget],
                                     "Average Math Score":[math_avg],
                                     "Average Reading Score":[read_avg],
                                     "% Passing Math":[math_pass_rate],
                                     "% Passing Reading":[read_pass_rate],
                                     "% Overall Passing Rate":[overall_avg]})

# %%
district_summary_df
# Out:
#    Total Schools  Total Students Total Budget  Average Math Score  \
# 0             15           39170    $24649428           78.985371
#
#    Average Reading Score  % Passing Math  % Passing Reading  \
# 0               81.87784       74.980853          85.805463
#
#    % Overall Passing Rate
# 0               80.431606

# %%
#School Summary

# %%
school_name=school_data_complete["school_name"]

# %%
school_type=school_data_complete["type"]

# %%
df=school_data_complete[["school_name", "student_name"]]

# %%
df
# Out:
#               school_name       student_name
# 0       Huang High School       Paul Bradley
# 1       Huang High School       Victor Smith
# 2       Huang High School    Kevin Rodriguez
# 3       Huang High School  Dr. Richard Scott
# 4       Huang High School         Bonnie Ray
# ...                   ...                ...
# 39165  Thomas High School       Donna Howard
# 39166  Thomas High School          Dawn Bell
# 39167  Thomas High School     Rebecca Tanner
# 39168  Thomas High School       Desiree Kidd
# 39169  Thomas High School    Carolyn Jackson
#
# [39170 rows x 2 columns]

# %%
df1=df.groupby("school_name").count()

# %% [markdown]
# df1

# %%
df1
# Out:
#                        student_name
# school_name
# Bailey High School             4976
# Cabrera High School            1858
# Figueroa High School           2949
# Ford High School               2739
# Griffin High School            1468
# Hernandez High School          4635
# Holden High School              427
# Huang High School              2917
# Johnson High School            4761
# Pena High School                962
# Rodriguez High School          3999
# Shelton High School            1761
# Thomas High School             1635
# Wilson High School             2283
# Wright High School             1800

# %%
df2=school_data_complete[["school_name", "budget",]]

# %%
df2
# Out:
#               school_name   budget
# 0       Huang High School  1910635
# 1       Huang High School  1910635
# 2       Huang High School  1910635
# 3       Huang High School  1910635
# 4       Huang High School  1910635
# ...                   ...      ...
# 39165  Thomas High School  1043130
# 39166  Thomas High School  1043130
# 39167  Thomas High School  1043130
# 39168  Thomas High School  1043130
# 39169  Thomas High School  1043130
#
# [39170 rows x 2 columns]

# %%
df3=df2.groupby("school_name").first()

# %%
df3
# Out:
#                         budget
# school_name
# Bailey High School     3124928
# Cabrera High School    1081356
# Figueroa High School   1884411
# Ford High School       1763916
# Griffin High School     917500
# Hernandez High School  3022020
# Holden High School      248087
# Huang High School      1910635
# Johnson High School    3094650
# Pena High School        585858
# Rodriguez High School  2547363
# Shelton High School    1056600
# Thomas High School     1043130
# Wilson High School     1319574
# Wright High School     1049400

# %%
merged1 = pd.merge(df1, df3, how="left", on=["school_name"])

# %%
merged1
# Out:
#                        student_name   budget
# school_name
# Bailey High School             4976  3124928
# Cabrera High School            1858  1081356
# Figueroa High School           2949  1884411
# Ford High School               2739  1763916
# Griffin High School            1468   917500
# Hernandez High School          4635  3022020
# Holden High School              427   248087
# Huang High School              2917  1910635
# Johnson High School            4761  3094650
# Pena High School                962   585858
# Rodriguez High School          3999  2547363
# Shelton High School            1761  1056600
# Thomas High School             1635  1043130
# Wilson High School             2283  1319574
# Wright High School             1800  1049400

# %%
merged2=merged1.rename({'student_name':'tot_student','budget':'tot_budget'},axis=1)

# %%
merged2
# Out:
#                        tot_student  tot_budget
# school_name
# Bailey High School            4976     3124928
# Cabrera High School           1858     1081356
# Figueroa High School          2949     1884411
# Ford High School              2739     1763916
# Griffin High School           1468      917500
# Hernandez High School         4635     3022020
# Holden High School             427      248087
# Huang High School             2917     1910635
# Johnson High School           4761     3094650
# Pena High School               962      585858
# Rodriguez High School         3999     2547363
# Shelton High School           1761     1056600
# Thomas High School            1635     1043130
# Wilson High School            2283     1319574
# Wright High School            1800     1049400

# %%
tot_student=merged2['tot_student']

# %%
tot_budget=merged2['tot_budget']

# %%
per_student=tot_budget/tot_student

# %%
per_student
# Out:
# school_name
# Bailey High School       628.0
# Cabrera High School      582.0
# Figueroa High School     639.0
# Ford High School         644.0
# Griffin High School      625.0
# Hernandez High School    652.0
# Holden High School       581.0
# Huang High School        655.0
# Johnson High School      650.0
# Pena High School         609.0
# Rodriguez High School    637.0
# Shelton High School      600.0
# Thomas High School       638.0
# Wilson High School       578.0
# Wright High School       583.0
# dtype: float64

# %%
df4=school_data_complete[["school_name", "math_score"]]

# %%
df4
# Out:
#               school_name  math_score
# 0       Huang High School          79
# 1       Huang High School          61
# 2       Huang High School          60
# 3       Huang High School          58
# 4       Huang High School          84
# ...                   ...         ...
# 39165  Thomas High School          90
# 39166  Thomas High School          70
# 39167  Thomas High School          84
# 39168  Thomas High School          90
# 39169  Thomas High School          75
#
# [39170 rows x 2 columns]

# %%
df5=df4.groupby('school_name').mean()

# %%
df5
# Out:
#                        math_score
# school_name
# Bailey High School      77.048432
# Cabrera High School     83.061895
# Figueroa High School    76.711767
# Ford High School        77.102592
# Griffin High School     83.351499
# Hernandez High School   77.289752
# Holden High School      83.803279
# Huang High School       76.629414
# Johnson High School     77.072464
# Pena High School        83.839917
# Rodriguez High School   76.842711
# Shelton High School     83.359455
# Thomas High School      83.418349
# Wilson High School      83.274201
# Wright High School      83.682222

# %%
merged3 = pd.merge(merged2, df4, how="left", on=["school_name"])

# %%
merged3
# Out:
#               school_name  tot_student  tot_budget  math_score
# 0      Bailey High School         4976     3124928          59
# 1      Bailey High School         4976     3124928          58
# 2      Bailey High School         4976     3124928          86
# 3      Bailey High School         4976     3124928          89
# 4      Bailey High School         4976     3124928          61
# ...                   ...          ...         ...         ...
# 39165  Wright High School         1800     1049400          82
# 39166  Wright High School         1800     1049400          95
# 39167  Wright High School         1800     1049400          99
# 39168  Wright High School         1800     1049400          91
# 39169  Wright High School         1800     1049400          80
#
# [39170 rows x 4 columns]

# %%
df5=school_data_complete[["school_name", "reading_score"]]

# %%
df6=df5.groupby('school_name').mean()

# %%
merged4 = pd.merge(merged3, df5, how="left", on=["school_name"])

# %%
merged4
# Out:
#                   school_name  tot_student  tot_budget  math_score  \
# 0          Bailey High School         4976     3124928          59
# 1          Bailey High School         4976     3124928          59
# 2          Bailey High School         4976     3124928          59
# 3          Bailey High School         4976     3124928          59
# 4          Bailey High School         4976     3124928          59
# ...                       ...          ...         ...         ...
# 130551925  Wright High School         1800     1049400          80
# 130551926  Wright High School         1800     1049400          80
# 130551927  Wright High School         1800     1049400          80
# 130551928  Wright High School         1800     1049400          80
# 130551929  Wright High School         1800     1049400          80
#
#            reading_score
# 0                     75
# 1                     84
# 2                     79
# 3                     71
# 4                     90
# ...                  ...
# 130551925             90
# 130551926             94
# 130551927             69
# 130551928             73
# 130551929             98
#
# [130551930 rows x 5 columns]
